# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36"
}

# %%
page_number=0
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36"
}

url = f"https://www.hepsiburada.com/yenilenmis-cep-telefonlari-c-80821000?sayfa={page_number}"

html = requests.get(url, headers=headers).content
soup = BeautifulSoup(html, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="tr">
# <head>
# <title>
#             Yenilenmiş Cep Telefonu Modelleri &amp; Fiyatları - Hepsiburada
#           </title>
# <link as="image" data-react-helmet="true" fetchpriority="high" href="https://productimages.hepsiburada.net/s/337/222-222/110000134860790.jpg" imagesrcset="https://productimages.hepsiburada.net/s/337/222-222/110000134860790.jpg/format:webp 1x, https://productimages.hepsiburada.net/s/337/444-444/110000134860790.jpg/format:webp 2x" rel="preload"/><link as="image" data-react-helmet="true" fetchpriority="high" href="https://productimages.hepsiburada.net/s/210/222-222/110000187470399.jpg" imagesrcset="https://productimages.hepsiburada.net/s/210/222-222/110000187470399.jpg/format:webp 1x, https://productimages.hepsiburada.net/s/210/444-444/110000187470399.jpg/format:webp 2x" rel="preload"/>
# <meta content="Yenilenmiş Cep Telefonu Modelleri &amp; Fiyatları - Hepsiburada" name="title"/>
# ...

# %%
st1 = soup.find("div" ,attrs={"class":"productListContent-pXUkO4iHa51o_17CBibU"}) #ulnin üstündeki
st2 = st1.find("ul", attrs={"class":"productListContent-frGrtf5XrVXRwJ05HUfU productListContent-rEYj2_8SETJUeqNhyzSm"})
#st2 #ul li olan
st3 = st2.find("li", attrs={"productListContent-zAP0Y5msy8OHn5z7T_K_"})
#st3 # li li olan

# %%
linksonu = st3.a.get("href")
linkbasi = "https://www.hepsiburada.com"
link = linkbasi + linksonu
link
# Out:
# 'https://www.hepsiburada.com/yenilenmis-apple-iphone-11-64-gb-12-ay-garantili-a-grade-p-HBCV00001DYM5Z'

# %%
r1= requests.get(link, headers=headers)
print(r1)
soup1 = BeautifulSoup(r1.content, "html.parser")
soup1   #200 kontrolü ve soup1 kontrolü
# Out:
# <Response [200]>
# <!DOCTYPE html>
#
# <html lang="tr">
# <head>
# <title>Yenilenmiş Apple iPhone 11 64 GB (12 Ay Garantili) - A Grade Fiyatı</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=8; IE=10; IE=11" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <meta content="Yenilenmiş Apple iPhone 11 64 GB (12 Ay Garantili) - A Grade Fiyatı" name="title"/>
# <meta content="Yenilenmiş Apple iPhone 11 64 GB (12 Ay Garantili) - A Grade en iyi fiyatla Hepsiburada&amp;#39;dan satın alın! Şimdi indirimli fiyatla sipariş verin, ayağınıza gelsin!" name="description"/>
# <meta content="E761AF3E6F8549DC23B070AB81390D26" name="msvalidate.01"/>
# <meta content="76ace7be824550d1" name="yandex-verification"/>
# ...

# %%
urun_adi = soup1.find("h1", attrs={"class":"product-name best-price-trick"}).text.strip()
urun_adi
# Out:
# 'Yenilenmiş Apple iPhone 11 64 GB (12 Ay Garantili) - A Grade'

# %%
fiyat = soup1.find("span", attrs={"data-bind":"markupText:'currentPriceBeforePoint'"}).text
fiyat
# Out:
# '15.131'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

page_number = 1
max_page = 5

liste = []

while page_number <= max_page:

    headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36"
    }
    
    url = f"https://www.hepsiburada.com/yenilenmis-cep-telefonlari-c-80821000?sayfa={page_number}"
    html = requests.get(url, headers=headers).content
    soup = BeautifulSoup(html, "html.parser")
    
    st1 = soup.find("div" ,attrs={"class":"productListContent-pXUkO4iHa51o_17CBibU"}) #ulnin üstündeki
    st2 = st1.find("ul", attrs={"class":"productListContent-frGrtf5XrVXRwJ05HUfU productListContent-rEYj2_8SETJUeqNhyzSm"})
    st3 = st2.find_all("li", attrs={"productListContent-zAP0Y5msy8OHn5z7T_K_"})

    for icerik in st3:
        linksonu = icerik.a.get("href")
        linkbasi = "https://www.hepsiburada.com"
        link = linkbasi + linksonu

        headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36"
        }

        r1= requests.get(link, headers=headers)
        soup1 = BeautifulSoup(r1.content, "html.parser")

        try:
            urun_adi = soup1.find("h1", attrs={"class":"product-name best-price-trick"}).text.strip()
            fiyat = soup1.find("span", attrs={"data-bind":"markupText:'currentPriceBeforePoint'"}).text
        except:
            print("bir hata ile karşılaşıldı")
            
        liste.append([urun_adi,fiyat])
        print(urun_adi, ":", fiyat)
        
    page_number+=1
    print(f"{page_number}. Sayfa işlemi tamamlandı.")
    
print("Tüm sayfalar dolaştı")
# Out:
# Yenilenmiş Apple iPhone 11 64 GB (12 Ay Garantili) - A Grade : 15.131
# Yenilenmiş Apple iPhone 11 128 GB (12 Ay Garantili) - A Grade : 17.167
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
# ...

# %%
df=pd.DataFrame(liste)
df.columns = ["urun_adı","urun_fiyatı"]
df
# Out:
#                                               urun_adı urun_fiyatı
# 0    Yenilenmiş Apple iPhone 11 64 GB (12 Ay Garant...      15.598
# 1    Yenilenmiş Apple iPhone 11 128 GB (12 Ay Garan...      17.698
# 2    Yenilenmiş iPhone 13 128 GB (12 Ay Garantili) ...      33.599
# 3    Yenilenmiş Apple iPhone 8 64 GB (12 Ay Garanti...       5.395
# 4    Yenilenmiş Apple iPhone 8 Plus 64 GB (12 Ay Ga...       7.979
# ..                                                 ...         ...
# 160       Yenilenmiş Samsung S3600i  (12 Ay Garantili)           0
# 161  Yenilenmiş Samsung Galaxy S4 Mini 8 GB (12 Ay ...           0
# 162  Yenilenmiş Samsung Galaxy S3 16 GB (12 Ay Gara...           0
# 163  Yenilenmiş Huawei P Smart 2018 64 GB (12 Ay Ga...           0
# 164     Yenilenmiş Samsung Galaxy J2 (12 Ay Garantili)           0
#
# [165 rows x 2 columns]

# %%
df.to_excel("hepsibburada_web-scraping.xlsx")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

page_number = 1
max_page = 5

liste = []

while page_number <= max_page:

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36"
    }
    
    url = f"https://www.hepsiburada.com/yenilenmis-cep-telefonlari-c-80821000?sayfa={page_number}"
    html = requests.get(url, headers=headers).content
    soup = BeautifulSoup(html, "html.parser")
    
    st1 = soup.find("div" ,attrs={"class":"productListContent-pXUkO4iHa51o_17CBibU"}) # ul'nin üstündeki
    if st1:
        st2 = st1.find("ul", attrs={"class":"productListContent-frGrtf5XrVXRwJ05HUfU productListContent-rEYj2_8SETJUeqNhyzSm"})
        if st2:
            st3 = st2.find_all("li", attrs={"class":"productListContent-zAP0Y5msy8OHn5z7T_K_"})

            for icerik in st3:
                linksonu = icerik.a.get("href")
                if linksonu:
                    linkbasi = "https://www.hepsiburada.com"
                    link = linkbasi + linksonu

                    try:
                        r1 = requests.get(link, headers=headers)
                        soup1 = BeautifulSoup(r1.content, "html.parser")

                        urun_adi = soup1.find("h1", attrs={"class":"product-name best-price-trick"}).text.strip()
                        fiyat = soup1.find("span", attrs={"data-bind":"markupText:'currentPriceBeforePoint'"}).text
                        
                        liste.append([urun_adi, fiyat])
                        print(urun_adi, ":", fiyat)
                    except Exception as e:
                        print("Bir hata ile karşılaşıldı:", e)
        else:
            print("İlgili ürün listesi bulunamadı.")
    else:
        print("Sayfa içeriği bulunamadı.")
        
    page_number += 1
    print(f"{page_number}. sayfa işlemi tamamlandı.")
    
print("Tüm sayfalar dolaşıldı.")

# Listeyi DataFrame'e çevirip dosyaya kaydetme
df = pd.DataFrame(liste, columns=["urun_adı", "Fiyat"])
#df.to_excel("hespiburada.xlsx", index=False)
print("Ürünler CSV dosyasına kaydedildi.")
# Out:
# Yenilenmiş Apple iPhone 11 64 GB (12 Ay Garantili) - A Grade : 15.836
# Yenilenmiş Apple iPhone 11 128 GB (12 Ay Garantili) - A Grade : 18.914
# Yenilenmiş Apple iPhone 8 Plus 128 GB (12 Ay Garantili) - A Grade : 8.359
# Yenilenmiş Apple iPhone 8 64 GB (12 Ay Garantili) - A Grade : 5.224
# Yenilenmiş Samsung Galaxy S22 5g 128 GB (12 Ay Garantili) - A Grade : 17.400
# Yenilenmiş Apple iPhone 7 Plus 32 GB (12 Ay Garantili) - A Grade : 4.800
# Yenilenmiş iPhone 13 128 GB (12 Ay Garantili) - B Grade : 30.399
# Yenilenmiş Apple iPhone SE 2020 64 GB 2.Nesil (12 Ay Garantili) - A Grade : 7.884
# Yenilenmiş Samsung Galaxy Note 20 Ultra 256 GB (12 Ay Garantili) - A Grade : 20.854
# Yenilenmiş Apple iPhone 8 Plus 64 GB (12 Ay Garantili) - A Grade : 7.599
# Yenilenmiş Samsung Galaxy A71 128 GB (12 Ay Garantili) - A Grade : 6.717
# Yenilenmiş iPhone 13 256 GB (12 Ay Garantili) - B Grade : 35.647
# Yenilenmiş Samsung Galaxy S20 Fe 128 GB (12 Ay Garantili) - A Grade : 8.036
# ...

# %%
df.to_excel("hespiburada-scraping.xlsx", index=False)
print("Ürünler XLSX dosyasına kaydedildi.")
# Out:
# Ürünler XLSX dosyasına kaydedildi.

# %%
#asıl çalışan bu sondaki, sadece bunu çalıştırınca yetiyor. küçük olan hepsiburada dosyasından link geliyor mu kontrol et
