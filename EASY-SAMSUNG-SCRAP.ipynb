# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# İlk sayfa numarası
page_number = 1
# Dolaşılacak maksimum sayfa sayısı
max_pages = 2

# Liste oluştur
liste3 = []

while page_number <= max_pages:
    url = f"https://easycep.com/kategori/samsung-4?page={page_number}"
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36"}

    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.content, "lxml")

    # Ürünlerin bulunduğu bölümü belirle
    st3 = soup.find_all("div", attrs={"class": "product__typeOne"})

    # Her bir ürün için
    for detaylar in st3:
        link_sonu = detaylar.a.get("href")
        link_basi = "https://easycep.com/"
        link = link_basi + link_sonu
        print(link)

        r1 = requests.get(link, headers=headers)
        soup1 = BeautifulSoup(r1.content, "lxml")

        fiyat = soup1.find("div", attrs={"class": "productDetail__price--text"}).text.strip()
        print(fiyat)

        urun_adi = soup1.find("h1", attrs={"class": "productDetail__title"}).text.strip()
        print(urun_adi)

        liste3.append([urun_adi, fiyat, link])

    page_number += 1
    print("Sayfa işlemi tamamlandı.")

# Liste kontrolü
print(liste3)
# Out:
# https://easycep.com//samsung-galaxy-s23-ultra-1-tb-siyah-cep-telefonu-12945
# 50.099,00 TL
# Samsung Galaxy S23 Ultra 1 TB Siyah
# https://easycep.com//samsung-galaxy-note-20-ultra-256-gb-siyah-cep-telefonu-2336
# 22.399,00 TL
# Samsung Galaxy Note 20 Ultra 256 GB Siyah
# https://easycep.com//samsung-galaxy-note-20-ultra-256-gb-bronz-cep-telefonu-2341
# 22.099,00 TL
# Samsung Galaxy Note 20 Ultra 256 GB Bronz
# https://easycep.com//samsung-galaxy-note-20-ultra-256-gb-siyah-cep-telefonu-2337
# 22.099,00 TL
# Samsung Galaxy Note 20 Ultra 256 GB Siyah
# https://easycep.com//samsung-galaxy-note-20-ultra-256-gb-beyaz-cep-telefonu-2333
# 22.099,00 TL
# Samsung Galaxy Note 20 Ultra 256 GB Beyaz
# https://easycep.com//samsung-galaxy-s22-plus-256-gb-pembe-cep-telefonu-3208
# 21.899,00 TL
# Samsung Galaxy S22 Plus 256 GB Pembe
# https://easycep.com//samsung-galaxy-z-flip4-128-gb-mor-cep-telefonu-11174
# 20.099,00 TL
# Samsung Galaxy Z Flip4 128 GB Mor
# https://easycep.com//samsung-galaxy-z-flip4-128-gb-mavi-cep-telefonu-11640
# 19.799,00 TL
# Samsung Galaxy Z Flip4 128 GB Mavi
# https://easycep.com//samsung-galaxy-s21-ultra-128-gb-siyah-cep-telefonu-2265
# 19.099,00 TL
# Samsung Galaxy S21 Ultra 128 GB Siyah
# https://easycep.com//samsung-galaxy-s22-128-gb-yesil-cep-telefonu-3162
# 18.499,00 TL
# Samsung Galaxy S22 128 GB Yeşil
# https://easycep.com//samsung-galaxy-s22-128-gb-siyah-cep-telefonu-3155
# 18.199,00 TL
# Samsung Galaxy S22 128 GB Siyah
# https://easycep.com//samsung-galaxy-s22-128-gb-beyaz-cep-telefonu-3152
# 17.899,00 TL
# Samsung Galaxy S22 128 GB Beyaz
# https://easycep.com//samsung-galaxy-s22-128-gb-yesil-cep-telefonu-3164
# 17.899,00 TL
# Samsung Galaxy S22 128 GB Yeşil
# https://easycep.com//samsung-galaxy-s22-128-gb-siyah-cep-telefonu-3156
# 17.899,00 TL
# Samsung Galaxy S22 128 GB Siyah
# https://easycep.com//samsung-galaxy-s22-128-gb-beyaz-cep-telefonu-3153
# 17.599,00 TL
# Samsung Galaxy S22 128 GB Beyaz
# https://easycep.com//samsung-galaxy-s22-128-gb-yesil-cep-telefonu-3165
# 17.599,00 TL
# Samsung Galaxy S22 128 GB Yeşil
# https://easycep.com//samsung-galaxy-s22-128-gb-siyah-cep-telefonu-3157
# 17.599,00 TL
# Samsung Galaxy S22 128 GB Siyah
# https://easycep.com//samsung-galaxy-note-20-256-gb-gri-cep-telefonu-2348
# 16.399,00 TL
# Samsung Galaxy Note 20 256 GB Gri
# https://easycep.com//samsung-galaxy-note-20-256-gb-bronz-cep-telefonu-2344
# 16.399,00 TL
# Samsung Galaxy Note 20 256 GB Bronz
# https://easycep.com//samsung-galaxy-note-20-256-gb-gri-cep-telefonu-2349
# 16.099,00 TL
# Samsung Galaxy Note 20 256 GB Gri
# https://easycep.com//samsung-galaxy-note-20-256-gb-bronz-cep-telefonu-2345
# 16.099,00 TL
# Samsung Galaxy Note 20 256 GB Bronz
# https://easycep.com//samsung-galaxy-note-20-256-gb-yesil-cep-telefonu-2353
# 16.099,00 TL
# Samsung Galaxy Note 20 256 GB Yeşil
# https://easycep.com//samsung-galaxy-z-flip3-128-gb-yesil-cep-telefonu-7113
# 15.599,00 TL
# Samsung Galaxy Z Flip3 128 GB Yeşil
# https://easycep.com//samsung-galaxy-z-flip3-128-gb-bej-cep-telefonu-5362
# 15.599,00 TL
# Samsung Galaxy Z Flip3 128 GB Bej
# https://easycep.com//samsung-galaxy-z-flip3-128-gb-yesil-cep-telefonu-7114
# 15.299,00 TL
# Samsung Galaxy Z Flip3 128 GB Yeşil
# https://easycep.com//samsung-galaxy-z-flip3-128-gb-mor-cep-telefonu-6135
# 15.299,00 TL
# Samsung Galaxy Z Flip3 128 GB Mor
# https://easycep.com//samsung-galaxy-z-flip3-128-gb-siyah-cep-telefonu-4230
# 15.299,00 TL
# Samsung Galaxy Z Flip3 128 GB Siyah
# https://easycep.com//samsung-galaxy-s21-plus-128-gb-siyah-cep-telefonu-3297
# 15.099,00 TL
# Samsung Galaxy S21 Plus 128 GB Siyah
# https://easycep.com//samsung-galaxy-s21-plus-128-gb-mor-cep-telefonu-3289
# 15.099,00 TL
# Samsung Galaxy S21 Plus 128 GB Mor
# https://easycep.com//samsung-galaxy-a73-128-gb-beyaz-cep-telefonu-11559
# 13.399,00 TL
# Samsung Galaxy A73 128 GB Beyaz
# Sayfa işlemi tamamlandı.
# https://easycep.com//samsung-galaxy-a73-128-gb-beyaz-cep-telefonu-11560
# 13.099,00 TL
# Samsung Galaxy A73 128 GB Beyaz
# https://easycep.com//samsung-galaxy-s21-fe-128-gb-mor-cep-telefonu-3145
# 12.299,00 TL
# Samsung Galaxy S21 FE 128 GB Mor
# https://easycep.com//samsung-galaxy-s21-128-gb-mor-cep-telefonu-3129
# 12.099,00 TL
# Samsung Galaxy S21 128 GB Mor
# https://easycep.com//samsung-galaxy-s21-128-gb-gri-cep-telefonu-3125
# 12.099,00 TL
# Samsung Galaxy S21 128 GB Gri
# https://easycep.com//samsung-galaxy-s20-128-gb-gri-cep-telefonu-2185
# 11.099,00 TL
# Samsung Galaxy S20 128 GB Gri
# https://easycep.com//samsung-galaxy-s20-128-gb-mavi-cep-telefonu-2169
# 11.099,00 TL
# Samsung Galaxy S20 128 GB Mavi
# https://easycep.com//samsung-galaxy-s20-128-gb-pembe-cep-telefonu-2177
# 11.099,00 TL
# Samsung Galaxy S20 128 GB Pembe
# https://easycep.com//samsung-galaxy-s20-plus-128-gb-siyah-cep-telefonu-2208
# 10.899,00 TL
# Samsung Galaxy S20 Plus 128 GB Siyah
# https://easycep.com//samsung-galaxy-s20-plus-128-gb-siyah-cep-telefonu-2209
# 10.599,00 TL
# Samsung Galaxy S20 Plus 128 GB Siyah
# https://easycep.com//samsung-galaxy-note-10-256-gb-gri-cep-telefonu-2373
# 10.099,00 TL
# Samsung Galaxy Note 10 256 GB Gri
# https://easycep.com//samsung-galaxy-s20-fe-256-gb-kirmizi-cep-telefonu-3977
# 10.099,00 TL
# Samsung Galaxy S20 FE 256 GB Kırmızı
# https://easycep.com//galaxy-a53-128-gb-siyah-cep-telefonu-10861
# 10.099,00 TL
# Galaxy A53 128 GB Siyah
# https://easycep.com//galaxy-a53-128-gb-turuncu-cep-telefonu-11564
# 10.099,00 TL
# Galaxy A53 128 GB Turuncu
# https://easycep.com//samsung-galaxy-s20-fe-128-gb-kirmizi-cep-telefonu-3957
# 9.399,00 TL
# Samsung Galaxy S20 FE 128 GB Kırmızı
# https://easycep.com//samsung-galaxy-s20-fe-128-gb-mor-cep-telefonu-3949
# 9.399,00 TL
# Samsung Galaxy S20 FE 128 GB Mor
# https://easycep.com//samsung-galaxy-s20-fe-128-gb-mavi-cep-telefonu-3945
# 9.399,00 TL
# Samsung Galaxy S20 FE 128 GB Mavi
# https://easycep.com//samsung-galaxy-a72-128-gb-siyah-cep-telefonu-5385
# 8.899,00 TL
# Samsung Galaxy A72 128 GB Siyah
# https://easycep.com//samsung-galaxy-a52s-128-gb-siyah-cep-telefonu-8129
# 8.699,00 TL
# Samsung Galaxy A52S 128 GB Siyah
# https://easycep.com//samsung-galaxy-s10-128-gb-siyah-cep-telefonu-2305
# 7.399,00 TL
# Samsung Galaxy S10 128 GB Siyah
# https://easycep.com//samsung-galaxy-note-10-lite-128-gb-gri-cep-telefonu-2381
# 7.399,00 TL
# Samsung Galaxy Note 10 Lite 128 GB Gri
# https://easycep.com//samsung-galaxy-m33-128-gb-mavi-cep-telefonu-13407
# 7.099,00 TL
# Samsung Galaxy M33 128 GB Mavi
# https://easycep.com//samsung-galaxy-s10e-128-gb-siyah-cep-telefonu-2217
# 5.899,00 TL
# Samsung Galaxy S10e 128 GB Siyah
# Sayfa işlemi tamamlandı.
# [['Samsung Galaxy S23 Ultra 1 TB Siyah', '50.099,00 TL', 'https://easycep.com//samsung-galaxy-s23-ultra-1-tb-siyah-cep-telefonu-12945'], ['Samsung Galaxy Note 20 Ultra 256 GB Siyah', '22.399,00 TL', 'https://easycep.com//samsung-galaxy-note-20-ultra-256-gb-siyah-cep-telefonu-2336'], ['Samsung Galaxy Note 20 Ultra 256 GB Bronz', '22.099,00 TL', 'https://easycep.com//samsung-galaxy-note-20-ultra-256-gb-bronz-cep-telefonu-2341'], ['Samsung Galaxy Note 20 Ultra 256 GB Siyah', '22.099,00 TL', 'https://easycep.com//samsung-galaxy-note-20-ultra-256-gb-siyah-cep-telefonu-2337'], ['Samsung Galaxy Note 20 Ultra 256 GB Beyaz', '22.099,00 TL', 'https://easycep.com//samsung-galaxy-note-20-ultra-256-gb-beyaz-cep-telefonu-2333'], ['Samsung Galaxy S22 Plus 256 GB Pembe', '21.899,00 TL', 'https://easycep.com//samsung-galaxy-s22-plus-256-gb-pembe-cep-telefonu-3208'], ['Samsung Galaxy Z Flip4 128 GB Mor', '20.099,00 TL', 'https://easycep.com//samsung-galaxy-z-flip4-128-gb-mor-cep-telefonu-11174'], ['Samsung Galaxy Z Flip4 128 GB Mavi', '19.799,00 TL', 'https://easycep.com//samsung-galaxy-z-flip4-128-gb-mavi-cep-telefonu-11640'], ['Samsung Galaxy S21 Ultra 128 GB Siyah', '19.099,00 TL', 'https://easycep.com//samsung-galaxy-s21-ultra-128-gb-siyah-cep-telefonu-2265'], ['Samsung Galaxy S22 128 GB Yeşil', '18.499,00 TL', 'https://easycep.com//samsung-galaxy-s22-128-gb-yesil-cep-telefonu-3162'], ['Samsung Galaxy S22 128 GB Siyah', '18.199,00 TL', 'https://easycep.com//samsung-galaxy-s22-128-gb-siyah-cep-telefonu-3155'], ['Samsung Galaxy S22 128 GB Beyaz', '17.899,00 TL', 'https://easycep.com//samsung-galaxy-s22-128-gb-beyaz-cep-telefonu-3152'], ['Samsung Galaxy S22 128 GB Yeşil', '17.899,00 TL', 'https://easycep.com//samsung-galaxy-s22-128-gb-yesil-cep-telefonu-3164'], ['Samsung Galaxy S22 128 GB Siyah', '17.899,00 TL', 'https://easycep.com//samsung-galaxy-s22-128-gb-siyah-cep-telefonu-3156'], ['Samsung Galaxy S22 128 GB Beyaz', '17.599,00 TL', 'https://easycep.com//samsung-galaxy-s22-128-gb-beyaz-cep-telefonu-3153'], ['Samsung Galaxy S22 128 GB Yeşil', '17.599,00 TL', 'https://easycep.com//samsung-galaxy-s22-128-gb-yesil-cep-telefonu-3165'], ['Samsung Galaxy S22 128 GB Siyah', '17.599,00 TL', 'https://easycep.com//samsung-galaxy-s22-128-gb-siyah-cep-telefonu-3157'], ['Samsung Galaxy Note 20 256 GB Gri', '16.399,00 TL', 'https://easycep.com//samsung-galaxy-note-20-256-gb-gri-cep-telefonu-2348'], ['Samsung Galaxy Note 20 256 GB Bronz', '16.399,00 TL', 'https://easycep.com//samsung-galaxy-note-20-256-gb-bronz-cep-telefonu-2344'], ['Samsung Galaxy Note 20 256 GB Gri', '16.099,00 TL', 'https://easycep.com//samsung-galaxy-note-20-256-gb-gri-cep-telefonu-2349'], ['Samsung Galaxy Note 20 256 GB Bronz', '16.099,00 TL', 'https://easycep.com//samsung-galaxy-note-20-256-gb-bronz-cep-telefonu-2345'], ['Samsung Galaxy Note 20 256 GB Yeşil', '16.099,00 TL', 'https://easycep.com//samsung-galaxy-note-20-256-gb-yesil-cep-telefonu-2353'], ['Samsung Galaxy Z Flip3 128 GB Yeşil', '15.599,00 TL', 'https://easycep.com//samsung-galaxy-z-flip3-128-gb-yesil-cep-telefonu-7113'], ['Samsung Galaxy Z Flip3 128 GB Bej', '15.599,00 TL', 'https://easycep.com//samsung-galaxy-z-flip3-128-gb-bej-cep-telefonu-5362'], ['Samsung Galaxy Z Flip3 128 GB Yeşil', '15.299,00 TL', 'https://easycep.com//samsung-galaxy-z-flip3-128-gb-yesil-cep-telefonu-7114'], ['Samsung Galaxy Z Flip3 128 GB Mor', '15.299,00 TL', 'https://easycep.com//samsung-galaxy-z-flip3-128-gb-mor-cep-telefonu-6135'], ['Samsung Galaxy Z Flip3 128 GB Siyah', '15.299,00 TL', 'https://easycep.com//samsung-galaxy-z-flip3-128-gb-siyah-cep-telefonu-4230'], ['Samsung Galaxy S21 Plus 128 GB Siyah', '15.099,00 TL', 'https://easycep.com//samsung-galaxy-s21-plus-128-gb-siyah-cep-telefonu-3297'], ['Samsung Galaxy S21 Plus 128 GB Mor', '15.099,00 TL', 'https://easycep.com//samsung-galaxy-s21-plus-128-gb-mor-cep-telefonu-3289'], ['Samsung Galaxy A73 128 GB Beyaz', '13.399,00 TL', 'https://easycep.com//samsung-galaxy-a73-128-gb-beyaz-cep-tel ...

# %%
df = pd.DataFrame(liste3)

df.columns = ["URUN_ADI","FIYAT","LINK"]
#df
df.to_excel("easy-samsung-web-scraping.xlsx")

# %%
#df.to_excel("easy-samsung-web-scraping.xlsx")
